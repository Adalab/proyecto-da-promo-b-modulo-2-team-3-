# %%
# Leemos el fichero con las pelis y generamos dos listas. Una de títulos y otra con los owner_id

# Importamos pandas para poder leer el csv y poder manejar el dataframe

import pandas as pd

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv('films_wo_duplicates.csv')

# Convertimos las columnas 'title' y 'owner_id' en listas
title_list = df['title'].tolist()
owner_id_list = df['owner_id'].tolist()

# Mostrar la lista para verificar que se ha creado correctamente
print(title_list)
print(owner_id_list)

#Esto Yanelis lo hace con list(df['owner_id])
# Out:
# ['Sanam Teri Kasam', 'Chinango', 'Blood and Bone', 'Whiteout', 'Sterling: The Secret of the Lost Medallion', 'Astro Boy', 'Watchmen', 'Harry Potter en de halfbloed prins', 'Royal Kill', 'Tekken', 'Venus & Vegas', 'The A-Team', 'Segurança Nacional', 'Scott Pilgrim vs. the World', 'Taken by Force', 'Guns, Drugs and Dirty Money', 'Komaram Puli', 'Spy', 'Cowboys & Aliens', 'Real Steel', 'Captain America: The First Avenger', 'Platinum Illusions', 'The Mechanic', 'Tower Heist', 'Season of the Witch', 'Foodfight!', 'John Carter', 'Clutch', 'Red Tails', 'Jack Reacher', 'Gallowwalkers', 'The Avengers', 'The Sweeney', 'Evangelion Shin Gekijôban: Kyu', 'The Amazing Spider-Man 3D', 'Alan Partridge: Alpha Papa', 'Without Warrant', 'Prisoners of the Sun', 'Man of Steel', 'R.I.P.D.', 'World War Z', 'The Power of Few', 'Epic', 'Snitch', 'Instruments of Darkness', 'A Walk Among the Tombstones', 'Action Jackson', 'The Equalizer', 'Sin City: A Dame to Kill For', 'Dil Ka Sauda', 'Jersey Justice', 'Dracu
# ...

# %%
df
# Out:
#       type                                       title  year     genre  \
# 0    Movie                            Sanam Teri Kasam  2009    Action
# 1    Movie                                    Chinango  2009    Action
# 2    Movie                              Blood and Bone  2009    Action
# 3    Movie                                    Whiteout  2009    Action
# 4    Movie  Sterling: The Secret of the Lost Medallion  2009    Action
# ..     ...                                         ...   ...       ...
# 524  Short                                      Astray  2023  Thriller
# 525  Movie                                Mom's Coming  2024  Thriller
# 526  Movie                             Killing Rainbow  2024  Thriller
# 527  Movie                                   Detour 95  2024  Thriller
# 528  Movie                  The Legend of Johnny Jones  2024  Thriller
#
#        owner_id
# 0     tt0205380
# 1     tt0312958
# 2     tt0346631
# 3     tt0365929
# 4     tt0373340
# ...

# %%
# Cargamos todas las librerías necesarias para web scrapping con Selenium
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
# no todas las películas están en rottentomatoes
# url para web scrapping de IMBd. Tendremos que sustituir el owner_id para que busque todas las películas
https://www.imdb.com/title/tt10928904/

# url para web scrapping de Rotten Tomatoes. Tendremos que sustituir el título de cada película para que busque la info de 
# todas las películas
https://www.rottentomatoes.com/m/the_legend_of_hillbilly_john

# %%
para hacer pruebas usar unos pocos elelemtos de la lista de películas
lista_id = lista_id

# %%
from tqdm import tqdm

# %%
# Navegamos a la página web "https://www.imdb.com/title/tt10928904/"

driver.get("https://www.imdb.com")

sleep(5)

driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-hLBbgP.sc-ftTHYK.dcvrLS.dufgkr.ecppKW").click()

owner_id_limited = owner_id_list [0:3]

for film in tqdm(owner_id_limited):
    score = None;

    try:
        #Introducimos el número de ID de la peli en el buscador de la web
        driver.find_element('css selector', '#suggestion-search').send_keys("film", Keys.ENTER)
        sleep(2)
        score = driver.find_element('css selector', '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-c41b9732-0.NeSef > section > div:nth-child(5) > section > section > div.sc-491663c0-4.gEsAEH > div.sc-491663c0-6.eQRCDK > div.sc-491663c0-11.bmRzqx > div.sc-3a4309f8-0.bjXIAP.sc-1f50b7c-5.dwZnUO > div > div:nth-child(1) > a > span > div > div.sc-eb51e184-0.kFvAju > div.sc-eb51e184-2.czkfBq > span.sc-eb51e184-1.cxhhrI').text
        print(score)
        
    except:
        score = 0;
        print(f'No ha sido posible obtener la puntuación de la película con ID:{film}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Navegamos a la página web "https://www.imdb.com/title/tt10928904/"
# ----> 3 driver.get("https://www.imdb.com")
#       5 sleep(5)
#       7 driver.find_element("css selector", "#__next > div > div > div.sc-jrcTuL.bPmWiM > div > button.icb-btn.sc-bcXHqe.sc-hLBbgP.sc-ftTHYK.dcvrLS.dufgkr.ecppKW").click()
#
# NameError: name 'driver' is not defined

# %%
# Inicializamos el navegador Chrome
driver = webdriver.Chrome()

# Navegamos a la página web "https://www.imdb.com/title/tt10928904/"
driver.get("https://www.imdb.com/title/tt10928904/")

#Inicializa el navegador de Chrome
#Hecho

#Navega a la página web principal
#Hecho

for film in tqdm(title_list):
    score = None;
    try:
        #Introducimos el número de ID de la peli en el buscador de la web
        driver.find_element('css selector', '#suggestion-search').send_keys(film, Keys.ENTER)
        sleep(2)
        score = driver.find_element('css selector', '#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.ipc-page-section--tp-xl.sc-51bb5dea-0.buxWIa > div.sc-fd9b6db2-0.gvAHjW > div:nth-child(2) > div:nth-child(1) > div.sc-f056af46-3.dzYxjh > div.sc-5931bdee-0.coHstx > div.sc-5931bdee-2.hUPAas > span.sc-5931bdee-1.gVydpF').text
        print(score)
    except:
        score = 0;
        print('No ha sido posible obtener la puntuación de la película con ID':pelicula')

# %%
# Inicializa el navegador Chrome
driver = webdriver.Chrome()

# Navega a la página web "http://www.adalab.es"
driver.get("https://www.imdb.com")

sleep(2)

driver.maximize_window()

sleep(2)

driver.find_element('css selector', '#suggestion-search').send_keys('tt0205380', Keys.ENTER)

sleep(2)

# Acepta las cookies haciendo clic en el elemento con el selector CSS "#wt-cli-accept-all-btn"
score = driver.find_element("css selector", "#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.ipc-page-section--tp-xl.sc-51bb5dea-0.buxWIa > div.sc-fd9b6db2-0.gvAHjW > div:nth-child(2) > div:nth-child(1) > div.sc-f056af46-3.dzYxjh > div.sc-5931bdee-0.coHstx > div.sc-5931bdee-2.hUPAas > span.sc-5931bdee-1.gVydpF").text

# Espera durante 5 segundos (esto puede ser útil para permitir que la página cargue completamente)
sleep(2)

# Captura una captura de pantalla de la página web actual y la guarda como "adalab.png"
# driver.save_screenshot('adalab.png')

# Cierra el navegador
print(score)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 18
#      15 sleep(2)
#      17 # Acepta las cookies haciendo clic en el elemento con el selector CSS "#wt-cli-accept-all-btn"
# ---> 18 score = driver.find_element("css selector", "#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.ipc-page-section--tp-xl.sc-51bb5dea-0.buxWIa > div.sc-fd9b6db2-0.gvAHjW > div:nth-child(2) > div:nth-child(1) > div.sc-f056af46-3.dzYxjh > div.sc-5931bdee-0.coHstx > div.sc-5931bdee-2.hUPAas > span.sc-5931bdee-1.gVydpF").text
#      20 # Espera durante 5 segundos (esto puede ser útil para permitir que la página cargue completamente)
#      21 sleep(2)
#
# ...

# %%
#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.ipc-page-section--tp-xl.sc-51bb5dea-0.buxWIa > div.sc-fd9b6db2-0.gvAHjW > div:nth-child(2) > div:nth-child(1) > div.sc-f056af46-3.dzYxjh > div.sc-5931bdee-0.coHstx > div.sc-5931bdee-2.hUPAas > span.sc-5931bdee-1.gVydpF

#__next > main > div > section > div > section > div > div.sc-978e9339-1.ihWZgK.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.ipc-page-section--tp-xl.sc-51bb5dea-0.buxWIa > div.sc-fd9b6db2-0.gvAHjW > div:nth-child(2) > div:nth-child(1) > div.sc-f056af46-3.dzYxjh > div.sc-5931bdee-0.coHstx > div.sc-5931bdee-2.hUPAas > span.sc-5931bdee-1.gVydpF
